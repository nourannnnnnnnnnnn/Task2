# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Downloads/SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Analyze Categories and Sub-Categories
category_sales = df.groupby('Category')['Sales'].sum()
category_profit = df.groupby('Category')['Profit'].sum()

# %%
# Visualize Category Sales
plt.figure(figsize=(8, 4))
category_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Category Profit
plt.figure(figsize=(8, 4))
category_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
subcategory_sales = df.groupby('Sub-Category')['Sales'].sum()
subcategory_profit = df.groupby('Sub-Category')['Profit'].sum()

# %%
# Visualize Sub-Category Sales
plt.figure(figsize=(10, 6))
subcategory_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Sub-Category Profit
plt.figure(figsize=(10, 6))
subcategory_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
# Assess Ship Mode and Segment
ship_mode_sales = df.groupby('Ship Mode')['Sales'].sum()
ship_mode_profit = df.groupby('Ship Mode')['Profit'].sum()

# %%
# Visualize Ship Mode Sales
plt.figure(figsize=(8, 4))
ship_mode_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Ship Mode Profit
plt.figure(figsize=(8, 4))
ship_mode_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()
segment_profit = df.groupby('Segment')['Profit'].sum()

# %%
# Visualize Segment Sales
plt.figure(figsize=(8, 4))
segment_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Segment Profit
plt.figure(figsize=(8, 4))
segment_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Segment')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
# Evaluate Discounts and Margins
discount_sales = df.groupby('Discount')['Sales'].sum()
discount_profit = df.groupby('Discount')['Profit'].sum()

# %%
# Visualize Discount Sales
plt.figure(figsize=(8, 4))
discount_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Discount')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Discount Profit
plt.figure(figsize=(8, 4))
discount_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Discount')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
# Review Regional Performance
region_sales = df.groupby('Region')['Sales'].sum()
region_profit = df.groupby('Region')['Profit'].sum()

# %%
# Visualize Region Sales
plt.figure(figsize=(8, 4))
region_sales.plot(kind='bar', color='blue')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize Region Profit
plt.figure(figsize=(8, 4))
region_profit.plot(kind='bar', color='green')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()
